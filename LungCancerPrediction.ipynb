# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
lung_data =pd.read_csv('/content/lung cancer survey.csv')

# %%
lung_data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
lung_data.shape
# Out:
# (309, 16)

# %%
lung_data.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# ...

# %%
lung_d=lung_data.drop(columns='GENDER',axis=1)

# %%
lung_data["LUNG_CANCER"].value_counts()
# Out:
# LUNG_CANCER
# YES    270
# NO      39
# Name: count, dtype: int64

# %%
lung_data.replace({'YES': 1 , 'NO':0})
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
X=lung_d.drop(columns='LUNG_CANCER',axis=1)
Y=['LUNG_CANCER']

# %%
print(X)
# Out:
#      AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 0     69        1               2        2              1                1
# 1     74        2               1        1              1                2
# 2     59        1               1        1              2                1
# 3     63        2               2        2              1                1
# 4     63        1               2        1              1                1
# ..   ...      ...             ...      ...            ...              ...
# 304   56        1               1        1              2                2
# 305   70        2               1        1              1                1
# 306   58        2               1        1              1                1
# 307   67        2               1        2              1                1
# 308   62        1               1        1              2                1
#
#      FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# ...

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
X=standardized_data
Y=lung_d['LUNG_CANCER']

# %%
print(X)
print(Y)
# Out:
# [[ 0.77185028 -1.13529242  0.86929961 ...  0.74873631  1.06350105
#    0.892475  ]
#  [ 1.38182914  0.88083033 -1.15035137 ...  0.74873631  1.06350105
#    0.892475  ]
#  [-0.44810745 -1.13529242 -1.15035137 ...  0.74873631 -0.94029056
#    0.892475  ]
#  ...
#  [-0.57010322  0.88083033 -1.15035137 ... -1.33558369 -0.94029056
#    0.892475  ]
#  [ 0.52785873  0.88083033 -1.15035137 ...  0.74873631 -0.94029056
#    0.892475  ]
#  [-0.08212013 -1.13529242 -1.15035137 ... -1.33558369  1.06350105
#   -1.12047956]]
# 0      YES
# 1      YES
# 2       NO
# 3       NO
# 4       NO
#       ...
# 304    YES
# 305    YES
# 306    YES
# 307    YES
# 308    YES
# Name: LUNG_CANCER, Length: 309, dtype: object

# %%
X_train , X_test ,Y_train ,Y_test =train_test_split (X,Y ,test_size=0.1,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (309, 14) (278, 14) (31, 14)

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Accuracy Test

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print("Accuracy of training data is:",training_data_accuracy)
# Out:
# Accuracy of training data is: 0.935251798561151

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print("Accuracy of training data is:",test_data_accuracy)
# Out:
# Accuracy of training data is: 0.9032258064516129

# %% [markdown]
# Making a Predictive System

# %%
input_data = (60,1,2,2,1,1,1,1,1,1,2,1,1,1)
input_data_as_numpy_array = np.asarray(input_data)

#Reshaping Data
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

#Standardizing the input data
standard_data=scaler.transform(input_data_reshaped)

prediction=classifier.predict(standard_data)
print(prediction)

if(prediction==['NO']):
  print("The person does not have lung cancer")
else:
  print("The person has lung cancer")
# Out:
# ['NO']
# The person does not have lung cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
